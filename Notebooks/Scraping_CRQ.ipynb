# %%
#Convert raw unlabelled CRQ data to list of lists and pickle
import pickle

data = open("../Data/CRQ/Unlabelled_crs.txt", 'r')

raw_data = data.read()
raw_data = raw_data.replace('""',"'")
raw_data_sep = raw_data.split('"')
raw_data_sep_nonempty = [element for element in raw_data_sep if element!="\n"]
for i in range(500):
    print(raw_data_sep_nonempty[i])
    print('------------------------------------')

pickle.dump( raw_data_sep_nonempty, open( "CRQ_1.pkl", "wb" ) )
# Out:
# ﻿MSG_All_Beschreibung_Anforderung
#
# ------------------------------------
# In CR492529 wurde die Anforderung umgesetzt, dass Während eines Overboost-Requests (Fahrerwunsch > LeadMax-Moment) nur die Boostphase 1+2 aktiviert werden sollen, die Phase 3 jedoch übersprungen werden sollen.;
# Problem:
# Fordert der Fahrer einen Overboost an, und sind währenddessen Boostphase 1+2 nicht möglich (z.B. aufgrund PWG-Wert, oder SOC), erhält der Fahrer kein Boostmoment. Aufgrund des oben genannten CR's würde die Phase 3 übersprungen werden.
# Geht dann jedoch die Fahrpedalstellung unter LeadMax zurück, würde die Boostphase 3 wieder aktiviert werden - der Fahrer bekäme bei Rücknahme des Fahrpedals mehr Moment.
# ------------------------------------
# Ist:
# Solange vom Fahrer kein Boost angefordert wird, wird immer das Boostmoment der Phase 1 freigegeben - unabhängig ob diese überhaupt verfügbar wäre.
# Bei einem Einstieg in den Boost wird auf das Boostmoment der ausgewählten Phase geschaltet. Die Umschaltung wird verrampt - dadurch kann es passieren, dass während der Verrampung zu viel Moment freigegeben wird.;
# Soll:
# Freigabe von Boostmoment passend zu Boostphase.
# ------------------------------------
# Derzeit kann der P-Anteil in Kennfeldern über Drehzahldifferenz (Differenz zwischen Istdrehzahl und der im MSG geformten Soll-Drehzahl) und dem Gradienten dieser Drehzahldifferenz appliziert werden. Der Gradient der Drehzahldifferenz zeigt bei Sprüngen der Soll-Drehzahl starke Ausschläge und kann daher nicht für alle Anwendungen genutzt werden.
# Diese Kennfeldeingänge ermöglichen es nur sehr schwer die unterschiedlichen, teils sehr geringen, Drehzahlsprünge beim Segelanbinden zu applizieren. Dies kann dazu führen, dass der Motor der Anbindeanforderung nicht folgen kann und es zu einem Ruck kommt.;
# Beispiel:
# Wenn eine Drehzahldifferenz von 2000 U/min ausgeregelt werden soll, muss das Moment bei einer Differenz von 200U/min schon wieder sehr stark zurückgenommen werden, um Drehzahlüberschwinger zu verhindern.
# Beträgt die Drehzahldifferenz bereits zu Beginn nur 200 U/min, reagiert der Motor nicht, da in diesem Bereich (resultierend aus dem ersten Fall) nur sehr wenig Moment appliziert werden kann.;
# Es soll für jeden Parametersatz möglich sein, applikativ zu wählen, ob die Kennfelder über Drehzahldifferenz und Gradient der Drehzahldifferenz – oder über Drehzahldifferenz und roher Soll-Drehzahl aufgespannt sein sollen.;
# Nur PT betroffen.
# ------------------------------------
# Derzeit kann der Momentengradient nach einem Synchrondrehzahleingriff vom Getriebe in einem Kennfeld über Gang und Regler-Soll-Moment appliziert werden.Diese Rampe ist in der Regel so appliziert, dass sie das Moment sehr schnell auframpt. Dies ist gewünscht für eine übertretene Schaltung.
# Beim Anbinden nach Segeln wird aktuell die gleiche Rampe genutzt, welche jedoch für diesen Anwendungsfall zu steil ist. Dadurch wird das Moment zu schnell aufgebaut, was für den Fahrer unplausibel sein kann.
#
# Es soll ein neues Kennfeld, abhängig von Regler-Soll-Moment und Fahrerwunsch-Moment, integriert werden. Damit kann bei Segel-Ausstieg je nach Fahrer-Anforderung der Gradient steiler/flacher bedatet werden.
# Es wird für jeden vom Getriebe angeforderten Parametersatz auswählbar sein, welches der beiden Rampenkennfeld genutzt werden soll.
#
# Nur PT betroffen.
# ------------------------------------
# Aktuell wird das im Synchrondrehzahleingriffsregler gebildete Sollmoment nur nach oben begrenzt.
# Es ist jedoch aktuell möglich, dass das Moment während einer Regelung sehr klein (z.B. -500Nm) wird. Dies kann passieren, wenn das Getriebeaufnahmemoment als Vorsteuerung des Reglers genutzt wird.
# Bei Eingriffsende initialisiert die anschließende Rampe auf diesem Moment, was zu einem für den Fahrer unplausiblen Momentenverlauf führt (keine Fahrzeugreaktion bis die Momentenrampe wieder Werte oberhalb des Schubmomentes erreicht hat).
# Darum soll das Set- und Leadmoment nach unten mit Pt_tqCluMin_VW gedeckelt werden.;
# Nur PT betroffen.
# ------------------------------------
# IST: Die Signalbeschreibung MO_Entkopplung_Sollschlupf besagt, dass das MSG vom GSG anfordern kann, das Anfahrelement (Fahr-/Wandlerkupplung) zu entkoppeln; das GSG soll die gesendete Drehzahl als Schlupf einstellen und ggf. die Regler-Parameter umschalten, damit Rucke aus dem Antrieb nicht im Fahrzeug spürbar werden; Das Signal ist nutzbar z.B. für Zustart VKM bei Hybrid-Projekten oder für Umschaltungen Halb-/Voll-Motor-Betrieb. Es soll auch für das optimierte elektrische Anfahren genutzt werden.
# Infolge CR477578 wird bei Sollschlupf der Betriebsartenkoordination von 0 U/min der Signalstatus MO_Entkopplung_Sollschlupf auf Init=1 gesetzt, was dazu führt, dass das Bus-Signal MO_Entkopplung_Sollschlupf den Initialwert (126dez) annimmt.
# Zur Absicherung gegen eine ungewollte Beschleunigung aufgrund fehlerhaftem Zufallen der Trennkupplung, wird auf dem Signal die Information 'Fahr-/Wandlerkupplung Öffnen' benötigt; Da das Getriebe das Öffnen der Kupplung, nicht aber die Sollschlupf-Einregelung mit der erforderlichen Sicherheitsintegrität bereitstellen kann, soll hierbei kein einzuregelnder Soll-Schlupf beinhaltet sein.
# PROBLEM: Mit der aktuellen Signalbelegung im MSG kann ein Sollschlupf von 0 U/min nicht gesendet werden, der jedoch für das optimierte elektrische Anfahren benötigt wird; Zudem kann die Information 'Fahr-/Wandlerkupplung öffnen' nicht gesendet werden, die für die Funktionssicherheit benötigt wird.
# ÄNDERUNG: Das Bus-Signal MO_Entkopplung_Sollschlupf soll so bedient werden, dass der korrekte Sollschlupf-Wunsch, ein Öffnen-Wunsch und auch die Information 'kein Wunsch vorhanden' enthalten ist.
# ------------------------------------
# Ist:
# In der Funktion LimTqEl wird neben dem maximalen Boostmoment zusätzlich ein prädiziertes maximales Boostmoment berechnet.
# Um dieses zu berechnen wird eine applizierbare Zeit 'in die Zukunft geschaut' (Wieviel Boostmoment wäre in X Sekunden freigegeben, wenn der Fahrer zu 100% auf dem Fahrpedal stehen würde?).
# In der aktuellen Umsetzung kann es während des Abintegrierens der zugehörigen Timer dazu kommen, dass das prädizierte Boostmoment nicht korrekt bestimmt wird.;
# Soll:
# Korrektur der Berechnung des prädizierten Boostmomentes.
# ------------------------------------
# Das Signal GE_Status_Kraftschluss wird aktuell in dem Modul %PtIf eingelesen und gegen evtl. anliegende Kommunikationsfehler plausibilisiert. Eine zusätzliche Plausibiliesierung prüft ab, ob das Getriebe einen in diesem Status nicht definierten Wert sendet. Anschließend wird das plausibilisierte Signal den nachfolgenden Nutzerfunktionen zur Verfügung gestellt.
# Mit der Version 2 des Signals kommt in dem Status die Belegung 5 (= geschlossen mit Überanpressung (wird im MQB nicht bedient)) hinzu.
# In der %PtIf muss deswegen der Wert 5 als regulärer Wert interpretiert werden.
# Nach aktueller Umsetzung würde bei einem empfangenen Wert 5 auf Fehler erkannt, was zu einem Abwurf der Reku führt.;
# Nur PT betroffen.
# ------------------------------------
# IST: Das prädizierte Momenten-Übersetzungsverhältnis zur Berechnung des prädizierten Fahrerwunschmoments wird aktuell angenähert durch das prädizierte Drehzahl-Übersetzungsverhältnis. Dieses wird berechnet aus der Anfragedrehzahl des Getriebe-SG bezogen auf die aktuelle Achsdrehzahl, die sich aus Radgeschwindigkeit und dem Radumfang ergibt.
# PROBLEM: Übersetzungsverhältnisse sind betragsmäßig definiert und werden auch so in den Nehmerfunktionen genutzt; Das prädizierte Übersetzungsverhältnis wird jedoch vorzeichenbehaftet berechnet aufgrund einer vorzeichenbehafteten Geschwindigkeit. Dies wirkt sich beim rückwärts Anfahren von PDKII-Fahrzeugen durch sehr schlechen Komfort aus.
# ÄNDERUNG: Anstatt der vorzeichenbehafteten Geschwindigkeit soll eine betragsmäßige Geschwindigkeit zur Berechnung des prädizierten Übersetzungsverhältnis genutzt werden.
# ------------------------------------
#
# Im Modul CordTqVehAx1d wird für Hybridfahrzeuge im Kennfeld CordTqVeh_tqCluSumAx1Max_M_VW das maximale Summenmoment für den Vortrieb in Abhängigkeit von Drehzahl und Boostphase appliziert. Für die Boostphasen sind aktuell allerdings nur 2 Stützstellen vorgesehen. Es gibt allerdings 5 Boostphasen, die hier auch abgebildet sein sollten, so dass die Anzahl der Stützstellen erweitert werden soll, weil sonst die Applikation nicht in der Lage ist die begrenzung korrekt zu applizieren.
#
# ------------------------------------
# IST: Im Paket Fahrerwunschaufnahme (DrvDemA) kann über Systemkonstante und Applikationsschalter gewählt werden, ob der Fahrerwunsch basierend auf Kupplungs- oder auf Radmoment ('Mastershift') berechnet wird. Beide Strategien führen zu unterschiedlichen Fahrverhalten: Beim kupplungsmomentenbasierten FW kann ein Momentenabfall nach einer Zughochschaltung appliziert werden; Beim radmomentenbasierten FW kann der Zielkonflikt zwischen Anfahr-Dynamik und Schaltkomfort aufgehoben werden. Bei Handschaltern macht nur die kupplungsmomentenbasierte Strategie Sinn. Wird er radmomentenbasiert berechnet, beeinflusst das Übersetzungsverhältnis - gesendet vom GSG - als Skalierungsfaktor maßgeblich das Kupplungsmoment. Die Drehzahl hingegen beeinflusst dann nur noch die Momentengrenzen.
# PROBLEM: Im Falle Mastershift ist das Fahrzeug nicht mehr fahrbar, wenn das eingerechnete Übersetzungsverhältnis falsch ist: Ist es z.B. fehlerhaft =0, so wird immer Volllast gestellt.
# SOLL: Wurde das Überetzungsverhältnis als fehlerhaft diagnostiziert (z.B. Bus-Übertragungsfehler), dann wird eine Fehlerersatzreaktion benötigt, um weiterhin das Fahrzeug beherrschen zu können und Drehmoment an die Kupplung stellen zu können. Vorschlag: Das Übersetzungsverhältnis vom 1. Gang nutzen, wodurch nur noch Fahrerwunschmoment für eine Fahrt auf Geschsindigkeiten unter ca. 50 km/h gestellt werden kann. Ist die Fehlerreaktion aktiv, so soll die EPC eingeschaltet werden, um dem Fahrer die erhebliche Funktionsreinschränkung anzuzeigen und zur Anfahrt der Werkstatt aufzufordern.
# ------------------------------------
# Istzustand:In den Konzern-Pt-Funktionen wird an mehreren Stellen die Bedingung 'Schubabschalten freigegeben' und 'Schubabschalten aktiv' referenziert um bestimmte Funktionalitäten auszulösen. Z.B. Sollmoment gleich Schubmoment, Abschaltung Lastpunktverschiebung. Bei Ottomotoren ist das notwendig, weil der Momentenbereich zwischen Minimalmoment bei spätest möglichen Zündwinkel und Reibmoment nur durch Einspritzausblendungen erreichbar ist. Dieselmotoren können ihr Moment kontinuierlich bis zum Reibmoment reduzieren. Da jedoch einige Objektfunktionen die Schnittstellen 'Schubabschalten freigegeben' und 'Schubabschalten aktiv' referenzieren wurden sie vom Zulieferer rudimentär angelegt. Die rudimentäre Umsetzung ist jedoch für die Nutzerfunktionen nicht ausreichend. Z.B.:
# - Rückkopplung zwischen der 'Freigabe Schubabschalten' und der 'Bedingung Schubabschalten' aktiv fehlt. Auswirkung: ist der Verbrenner einmal im Schubabschalten muss das Fahrerwunschmoment über die Stellgrenzen der Elm ansteigen, bis der Verbrenner wieder Moment stellt.
# - die Lastpunktverschiebung wird mit der 'Bedingung Schubabschalten' freigegeben deaktiviert und wird erst wieder aktiv wenn die Drehzahl unter eine applizierbare Schwelle sinkt. Bei erhöhter Leerlaufdrehzahl wird diese Schwelle unter Umständen nie unterschritten, die Lastpunktverschiebung bleibt dauerhaft deaktiviert, die HV-Batterie kann tiefentladen werden
# - Für die Berechung des Vorsteuermoment im Leerlauf wird in der Funktion %PtTqLoss lokal die Bedingung Schubabschalten aktiv berechnet, ohne Rückkopplung zu den Signalen vom Zulieferer.
#
#
# Sollzustand:
# Sämtliche im Anhang aufgeführte Nutzerfunktionen müssen prüfen, ob sie die Information 'Schubabschalten freigegeben' und 'Schubabschalten aktiv' bei Dieselprojekten benötigen. Für alle Funktionen, die diese Information benötigen, soll zentral eine Bedingung im Objekt berechnet werden, mit der Information: keine Momentenanforderung für Verbrenner aktiv.
# Die Berechnung der 'Freigabe Schubabschalten' beim Zulieferer soll entfallen. Die Berechnung der Bedingung 'Schubabschalten aktiv' soll angepasst werden.
# ------------------------------------
# Im Modul des Höchstdrehzahlreglers (SpdCtlMax) wird die Parametrierung des Reglers umgeschaltet, je nachdem ob der Triebstrang offen oder geschlossen ist. Diese Information wird aus dem Modul CordSpdCtl entnommen (CordSpdCtl_bVehMot_VW). Diese Information wird gleichzeitig auch für die Umschaltung des Leerlaufreglers genutzt.
# Der Leerlaufregler und der Höchstdrehzahlregler haben allerdings unterschiedliche Anforderungen an das Signal. Für den Leerlaufregler ist es notwendig, möglichst schnell auf den Parametersatz für offenen Triebstrang zu wechseln, sobald bereits ein Verdacht auf offenen Triebstrang vorliegt, um sicherzustellen, dass der Motor nicht abgewürgt wird. Beim Höchstdrehzahlregler führt ein zu frühes Umschaltung zu starken Drehzahlschwingungen, wenn mit den 'Offen-Parametern' der geschlossene Triebstrang geregelt wird.;
# Aus diesem Grund ist es notwendig eine getrennte Applikation dieser Erkennungsschwellen zu schaffen.
# ------------------------------------
#
# Ganz wichtige Korrektur in Freigabe-Modul für NOx-Rohemissionsmodell
#
# ------------------------------------
# Die Antiruckelfunktion wird abhängig von vielen Systemzuständen freigegeben oder gesperrt (siehe Attachment).
# Für eine einfache und schnelle Analyse der Funktion soll ein Statuswort gebildet werden, welches anzeigt, welche Bedingung zu einem Verbot eines Antiruckeleingriffs geführt hat.
# ------------------------------------
# Im Schub (keine Fahrerwunschanforderung) soll wenn möglich die Einspritzung abgeschalten werder um Kraftstoff zu sparen. Der Übergang vom befeuerten Betrieb ins Schubabschalten muss aus Komfortgründen kontinuierlich erfolgen. Ein Ottomotor kann den Bereich unter dem Minimalmoment beim spätesten möglichen Zündwinkel und seinem Reibmoment nur stellen, wenn bei mindestens einem Zylinder die Einspritzung ausgeblendet wird. Dieser Bereich wird in der Momentenstruktur nur freigegeben, wenn die Freigabe für Schubabschalten gesetzt ist. Bei gesetzter Freigabe wird die untere Grenze des erlaubten Momentenbereichs vom Minimalmoment beim spätesten möglichen Zündwinkel zum Reibmoment gerampt.Durch die aktuelle Umsetzung der Rampenfunktionalität bleibt allerdings die untere Grenze des erlaubten Momentenbereichs eingefroren, wenn das Reibmoment schneller als der Rampengradient ansteigt. Z.B. durch eine Reduzierung der Last. Dadurch wird zu viel Moment gestellt, der Verbrenner dreht bei getretener Kupplung ungewollt hoch.
#
# Soll:
# Bei erfolgter Freigabe für Schubabschalten muss die untere Grenze des erlaubten Momentenbereichs stetig Richtung Reibmoment gerampt werden, unabhängig vom Gradienten des Reibmomentes.
# ------------------------------------
# Aktuell sind beim Stopp des Verbrennungsmotors Einspritzausblendungen nicht erlaubt. Waren zum Beispiel vor dem Stopp Einspritzausblendungen freigegeben und im Stoppvorgang nicht, dreht der Verbrenner bei offener K0 über die Elm Drehzahl hoch und schneidet nach der Vollausblendung die Elm Drehzahl (siehe Messung anbei). Das Verhalten hat zwei unerwünschte Auswirkungen. zum einen ist das Hochdrehen des Verbrenners auf einem vorhandenen Drehzahlmesser sichtbar und somit irritierend für den Fahrer, der Aufgrund des Motorstopps eine absinkende Drehzahl erwartet. Zum anderen ist das Drehzahlschneiden von Verbrenner und Elm bei einem vorhandenen Restschleppmoment an der K0 als leichter Ruck im Fahrzeug spürbar.;
# Soll:
# Im Motorstopp sollen Einspritzausblendungen erlaubt werden, damit die Verbrennerdrehzahl nicht über die Elm-Drehzahl ansteigt.
# ------------------------------------
# Das Bussignal MO_Mom_neg_verfuegbar sollte für den MLB Hybrid mit blendingfähigen Bremssystem das verfügbare Rekuperationsmoment auf Kupplungsebene angeben. Für die MQB und MLB evo Vernetzung ist MO_Mom_neg_verfuegbar entfallen, d.h. auch die Berechnung in der PtCom kann entfallen. Für MQB und MLB evo wird das verfügbare Rekuperationsmoment auf Radebene durch die Signale TS_min_Generatormoment, bzw. TS_MomRad_verfuegb_maxReku angegeben.
# Die zur Berechnung von MO_Mom_neg_verfuegbar verwendete Größe Pt_tqBrkRcpMin_VW, die angibt wie viel Bremsrekuperationsmoment auf Kupplungsebene vom Antriebsstrang freigegen ist, soll ebenfalls entfallen. Pt_tqBrkRcpMin_VW wird von der Hauptschiene der %DrvDemBrk nicht mehr zur Verfügung gestellt.
# Die verfügbaren Rekuperationsmomente auf Radebene TS_min_Generatormoment, bzw. TS_MomRad_verfuegb_maxReku werden direkt in der PtCom berechnet.
# ------------------------------------
# IST: Das prädizierte Momenten-Übersetzungsverhältnis zur Berechnung des prädizierten Fahrerwunschmoments wird aktuell angenähert durch das prädizierte Drehzahl-Übersetzungsverhältnis. Dieses wird berechnet aus der Anfragedrehzahl des Getriebe-SG bezogen auf die aktuelle Achsdrehzahl, die sich aus Radgeschwindigkeit und dem Radumfang ergibt. Beim Anfahren soll das Fahrerwunschmoment bei schlupfender Kupplung prädiziert werden.
# PROBLEM: Ist der Antriebsstrang offen, dann ist das Drehzahl-Übersetzungsverhältnis keine sinnvolle Näherung für das Momenten-Übersetzungsverhältnis. Die entsprechende Berechnung führt im Getriebe zu einem sehr unkomfortablen Anfahren.
# ÄNDERUNG: In den Getriebestatus (GE_Getriebestatus_02), in denen das Getriebe ein Fahrerwunschmoment in schlupfendem Zustand anfragt, soll das prädizierte Übersetzungsverhältnis durch das aktuelle angenähert werden.
# ------------------------------------
# IST:
# In der VehDynCtl_Esc gibt es - außer der ESP-Schnittstelle - einen zusätzlichen Teil für die Hybrid-Projekte, um die Rekuperationsanforderungen vom ESP (bzw. Bremse) einzukoordinieren.
# Da das ESP-Steuergerät für die Rekuperation nur Radmoment sendet, ist es wichtig, dass die VehDynCtl_Esc auch alle Applikationslabels und interne Signale als Radmoment kennzeichnet, um eine falsche Bedatung (Kupplung- statt Radmoment) zu vermeiden.
#
# SOLL:
# Die betroffenen Labels sind schon als Radmomente definiert (der Wertbereich ist richtig), es müssen aber noch die Namen der Labels und internen Signale angepasst werden. (z.B. VehDynCtl_tqRcp... _VW--> VehDynCtl_tqWhlRcp..._VW)
# ;
# nur PT
# ------------------------------------
# IST
# Bisher wurde in der VehDynCtl_Esc die Einkoordinierung der ESC-Anforderungen mittels ein Rampe zu -120Nm (Kupplungsebene) abgebrochen, sobald das Getriebe keinen sicheren Gang eingelegt meldet. Das sollte über ein Q-Bit1 vom Getriebe signalisiert werden.
#
# PROBLEM
# Diese Konzept (QBit1) wird nicht mehr weiterverfolgt. Stattdessen ist ein Q-Bit3 definiert worden, welches die Übertragungsfunktion GE_Uefkt plausibilisiert.
#
# SOLL
# Das Q-Bit3 soll in der VehDynCtl_Esc eingelesen werden, um das verfügbare Rekuperationsmoment bei nicht plausibler Übertragungsfunktion herunterzurampen.
#
# nur PT
# ------------------------------------
# IST
# in der VehDynCtl_Esc ist die Reihenfolge der Begrenzungen des Rekumomentes so umgesetzt, dass die Gradientenbegrenzung vom Getriebe immer die höchste Priorität hat.
# Die Gradientenbegrenzung stellt sicher, dass während einer Schaltung das Moment nicht zu schnell verändert wird.
# In dem Fall einer Abschaltung würde aber auch die Abschaltung langsam abgerampt werden.
#
# PROBLEM
# Während einer Abschaltung wird das Rekumoment auf 0 gerampt. Ist der zulässige Getriebegradient allerdings kleiner, wird das Moment entsprechend langsamer weggerampt.
# Dadurch steht bei einer Abschaltung länger als vorgesehen Moment an.
# Zusätzlich ist der Gradient während einer Abschaltung fix - auch wenn bei geringeren Momenten die Verrampung nicht so schnell stattfinden müsste.
#
# SOLL
# Die Verrampung während einer Abschaltung soll die höchste Priorität bekommen.
# Die Verampung des Moments im Fehlerfall soll Zeit- und Gradientenabhängig sein.
# ------------------------------------
# Nach einem Getriebedrehzahleingriff wird eine Momentenrampe (vom letzten Reglermoment zum Fahrerwunschmoment) ausgeführt.
# Dabei ist der Zündungspfadverlauf exakt bedatbar, der Luftpfad wird (abhängig vom letzten Eingriffsmoment) so geführt, dass das Rampenziel im selben Rechentask erreicht wird.
# Applikativ besteht zusätzlich die Möglichkeit den Luftpfad über 2 Faktorkennlinien (Rampe nach oben bzw. Rampe nach unten) zu beeinflussen.
# Beide Kennlinien sind abhängig von dem aktuell anliegenden Regler-Zündwinkel-Soll-Moment.
# Bei negativen Rampen kann es (z.B. wegen einem aufgezogenen Regler-I-Anteil) dazu kommen, dass das Zündungsmoment tief, das Luftmoment jedoch hoch ist.
# In diesem Zustand soll das Luftmoment sehr schnell abgebaut werden, was aber am aktuell genutzten Kennlinieneingang nicht zu erkennen ist, da das Zündungsmoment keinen direkten Bezug zum Luftmoment aufweist. Im ungünstigsten Fall kann es zu einem unangenehmen nachschieben des Fahrzeugs kommen.
# Darum soll für die Rampe nach unten die Möglichkeit geschaffen werden, dass als Kennlinieneingang applikativ zwischen dem Regler-ZW-Soll-Moment und dem Regler-Soll-Luftmoment gewählt werden kann.;
# nur PT betroffen
# ------------------------------------
# Derzeit wird die Zündwinkel-Rampe generell mit dem kleineren Wert aus letztem Regler-Zündwinkel-Soll-Moment und dem Ist-Zündwinkel-Moment initialisiert, die Luft-Rampe dagegen mit dem Regler-Luft-Soll-Moment
# Dies kann in manchen Situationen dazu führen, dass die Rampe länger als nötig läuft, was dem Fahrer als ungewohnt lange Schaltung auffällt.
#
# In ZW-Rampe soll abhängig von der Rampen-Richtung wie folgt initialisiert werden:
# Wenn der Zielwert (Fahrerwunsch) sowohl größer als das aktuelle Ist-Zündwinkel-Moment als auch größer als das Regler-Zündwinkel-Soll-Moment ist, dann soll die Rampe mit dem Ist-Moment initialisieren.
# In allen übrigen Fällen soll die Rampe wie bisher mit MIN aus Regler-Zündwinkel-Soll-Moment und dem Ist-Moment initialisieren.
# Grund: wenn Ziel > Ist > Regler, dann soll auf dem höheren Ist-Moment initialisiert werden ->Zeitdauer der Rampe nach oben verringert sich.
#
# Die Luft-Rampe soll abhängig von der Rampen-Richtung wie folgt initialisiert werden:
# Wenn der Zielwert (Fahrerwunsch) sowohl kleiner als das aktuelle Ist-Luft-Moment (Basismoment) als auch kleiner als das Regler-Luft-Soll-Moment ist, dann soll die Rampe mit dem MIN aus letztem Regler-Luft-Soll-Moment und Ist-Luft-Moment initialisiert werden.
# In allen übrigen Fällen soll die Rampe wie bisher mit dem Regler-Luft-Soll-Moment initialisiert werden.
# Grund: wenn Ziel < Ist < Regler würde mit dem kleineren Ist-Moment inialisiert werden -> Zeitdauer der Rampe nach unten verringert sich + geringeres Risiko, dass Luft zu lange hoch gehalten wird .
#
# betrifft nur PT
# ------------------------------------
# Derzeit kann für jeden Parametersatz getrennt appliziert werden, ob der dynamische Anteil auf die Vorsteuerung für den schnellen Pfad einkoordiniert werden soll oder nicht; für den Luftpfad besteht keine Applikationsmöglichkeit, da das Vorsteuermoment für den schnellen Pfad die Basis ist für das Vorsteuermoment für den Luft-Pfad.In Zukunft soll es auch für den Luft-Pfad für jeden Parametersatz getrennt applizierbar sein, ob der dynamische Anteil dort einkoordiniert werden soll oder nicht [die Änderung wäre 100% rückwärtskompatibel zur heutigen Funktion].
#
# Grund: es soll möglich sein, den dynamischen Anteil zwar in den schnellen Pfad einzukoordinieren, aber nicht in den Luftpfad; Anwendungsfall wären Hochschaltungen, in denen aus der dynamischen Vorsteuerung ein negativer Anteil käme, der nicht auf die Luft gerechnet werden soll.
#
# Änderung betrifft nur PT.
# ------------------------------------
# Derzeit wird das mögliche Luft-Vorhaltemoment auf Basis des Fahrerwunschmoments gebildet, das dann per Faktor gewichtet oder gedeckelt werden kann.In Zukunft soll das Vorhaltemoment auf Basis des Zündwinkel-Vorsteuermoments gebildet werden und nicht nur aus ZW-Wirkungsgrad (heutiger Zustand) berechnet werden, sondern auch die aktuell aktive Ausblendung berücksichtigen (diese wirkt sich, auf Grund der dadurch entstehenden Momentenreduzierung, direkt auf das maximal stellbare Motormoment aus und muss darum in der Berechnung des Luft-Vorhaltemomentes mit einbezogen werden).
#
# Grund: mit max. Vorsteuerung könnte man gerade noch das Soll-Moment einstellen, mit faktorieller Bewertung bzw. mit Deckelung kann man einstellen, wieviel Stellbereich man dem Regler läßt [diese Änderung ist nicht rückwärtskompatibel, die Teil-Funktion ist über SC nur in Otto-Projekten aktiv und wird derzeit nur von Porsche genutzt].
#
# nur PT betroffen
# ------------------------------------
# Derzeit gibt es für Momenten-Eingriffe folgende Umsetzungs-Möglichkeiten, abhängig von Signal GE_MMom_Status_02:-       Wenn GE_MMom_Status_02 = 1, dann wir ein absoluter, reduzierender Eingriff umgesetzt, rein auf den schnellen Pfad, d.h. über Zündwinkel-Verstellung + evtl. Ausblendung
# -       Wenn GE_MMom_Status_02 = 6, dann wird ein absoluter, reduzierender Eingriff auf Schnellen Pfad und Luft-Pfad (laut Bus-Signal-Beschreibung) umgesetzt; in der MSG-Software wird dabei der Luftpfad genauso stark reduziert wie der schnelle Pfad
#
# In Zukunft soll die Möglichkeit bestehen, einen reduzierenden Eingriff so einzukoodinieren, dass der Luftpfad nur so weit reduziert wird, dass das Soll-Moment über ZW-Verstellung eingestellt werden kann.
# Es soll dafür die MSG-Software erweitert werden, dass für GE_MMom_Status_02 = 6 im MSG appliziert werden kann, ob der Luft-Pfad auf den gleichen Wert wie der Schnelle Pfad oder nur so weit wie nötig reduziert werden soll [die Änderung wäre 100% rückwärtskompatibel zur heutigen Funktion].
# Das hat den Verteil, dass der Momentenaufbau nach dem reduzierenden Eingriff wieder schneller erfolgen kann.
#
# betrifft nur PT
# ------------------------------------
# Um auf Zuliefererseite das innere Moment sicher auf 0 schalten zu können, wenn sich das Fahrzeug im Schub befindet, wird das Bit Pt_b_tqDesEngIdc0_VW gebildet. Hierfür wird ermittelt, ob das Ausgangsmoment des Konzern-Powertrains Pt_tqDesEng_VW kleiner oder gleich dem minimal an der Kurbelwelle stellbaren Moment (Eng_tqCkMin_VW = Reibmoment) plus einem applizierbaren Offset (CordTqLim_tqOfsDesEngIdc0_C_VW) ist.
# Wenn sich das Ausgangsmoment des Powertrains nun genau an dieser durch minimales Moment plus Offset definierten Schwelle befindet, kann es durch geringe Momentenschwankungen zu wiederholtem hartem Ein- und Ausschalten der Verbrennung kommen.;
# Lösungsvorschlag: Es soll eine Hysterese zu Bildung von Pt_b_tqDesEngIdc0_VW implementiert werden.
# ------------------------------------
# Anforderung von EADA (M.Greiner, I.Koertje):
# Bei kaltgestarten Fahrzyklus soll im Schub mit AGR gefahren werden, um im Schub ein Auskühlen des SCRKats zu vermeiden. Um OBD-Fehler erkennen zu können, müssen warmgestarteteFahrzyklen im Schub ohne AGR gefahren werden (Anforderer:EAES/4,  F.Alich).
#
# Eine weitere Adaptionsfreigabe soll abhängig von der Kühlmittelstarttemperatur erfolgen. Bei kleinen Kühlmittelstarttemperaturen (Kaltstart) soll eine applizierbare Zeit abgewartet werden, bis die zusätzliche Freigabe erfolgt. Bei hohen Kühlmittelstarttemperaturen (Warmstart) kann diese zusätzliche Freigabe sofort erfolgen.
# ------------------------------------
# In Hybridprojekten kann eine Verzögerung im ACC- oder Limiterbetrieb durch eine Rekupration an der EM-dargestellt werden. Um zu verhindern, dass dabei der Verbrennungsmotor abgewürgt wird, muss ein Abwürgeschutz vorgesehen werden, der dafür sorgt, dass das EM-Moment zurückgenommen wird und wenn möglich der Verzögerungswunsch auf das Bremssystem überblendet wird.;
# Aktuell ist dies Verhalten noch nicht sichergestellt. Daher soll das bereits vorhandene Abwürgeschutzmoment Pt_tqCliMinStallProt_VW in der Momentenkoordination in der DrvDemCord als untere Triebstranggrenze auf DrvDemCord_tqWhlMin eingerechnet werden, so dass keine Momentenanforderung dieses Moment unterbieten kann.
# ------------------------------------
# Bei Hybridfahrzeugen kann das Getriebesteuergerät (GSG) für den Zustart des Verbrennungsmotors (VKM) einen Momenteneingriff auf die E-Maschine (EM) vornehmen, um das Moment, das an der K0 für den VKM-Hochlauf abgenommen wird, zu kompensieren (Kompensationsmoment). Wenn gleichzeitig ein Getriebeschutzeingriff vorliegt, kann es dazu kommen, dass das Kompensationsmoment nicht gestellt wird. Dies führt dazu, dass das EM-Moment zum Hochdrehen der VKM nicht ausreicht und somit das K0-Moment am Rad wirksam wird, was für den Fahrer als spürbarer Momenteneinbruch wahrnehmbar ist. Dies ist unkomfortabel und soll vermieden werden.;
# Da sich das Getriebeschutzmoment auf die Getriebeeingangsseite bezieht und das Kompensationsmoment auf die andere Seite der EM, sollen diese beiden Momente in Systemen, bei denen die K0-Ansteuerung im GSG liegt, getrennt betrachtet werden, so dass sich ein im MSG empfangenes Getriebeschutzmoment nicht limitierend auf das ebenfalls vom GSG gesendete Kompensationsmoment auswirkt, da in der beschriebenen Konstellation davon ausgegangen werden kann, dass das K0-Moment exakt dem Kompensationsmoment entspricht und somit kein Einfluss des Kompensationsmoments auf das Moment am Getriebeeingang vorliegt.
# ------------------------------------
# Wenn bei stehendem Fahrzeug das Fahrpedal durchgetreten ist, wird die Motordrehzahl über die Standdrehzahlbegrenzung limitiert. Wenn dieser Zustand länger anhält, tritt die sog. Toter-Mann-Funktion in Kraft. Diese reduziert die maximal zugelassene Drehzahl noch einmal deutlich, z.B. auf 1200 rpm. Die Umsetzung der Sollwertvorgabe erfolgt in der %SpdDesMax über eine Umschaltung.Die sprunghafte Umschaltung des Maxdrehzahlsollwertes führt zu einer entsprechend ruppigen Reaktion des Motors, da dessen Moment schlagartig reduziert wird, um den neuen Maxdrehzahlsollwert einzuregeln. Das wird als unkomfortabel empfunden.
#
# Um den Komfort zu verbessern, soll der Drehzahlsollwert bei Aktivierung der Toter-Mann-Funktion über eine Rampe auf den neuen Wert geführt werden.
# ------------------------------------
# IST: Im Q7 PHEV wird ein Fahrpedal-Druckpunkt bei dem Pedalwert aufgeschaltet, das dem Drehmoment entspricht, dessen Überschreitung den Zustart des Verbrennungsmotors im EV-Modus zur Folge hat. Dabei wird nicht beachtet, ob das Fahrerwunschmoment vom Fahrpedal geführt wird oder von einem Fahrerassistenzsystem. Eine applikative Konfiguration erlaubt es dabei, den Druckpunkt mit aktiviertem EV-Modus immer aktiv zu halten, auch wenn im die aktuell anliegenden Betriebsstrategie 'hybrid' ist.
# PROBLEM: Wenn der Fahrerwunsch vom Limiter-Moment geführt wird und das maximale elektrische Moment oberhalb des Limiter-Moments steht, dann löst ein Übertreten des Druckpunktes keinen Verbrenner-Zustart aus. Denn das vom Fahrpedal geforderte Moment wird in dem Fall durch den Limiter beschnitten. Das ist für den Fahrer nicht nachvollziehbar. Außerdem, in der oben genannten Applikation bei aktiv regendem ACC/GRA-Moment oberhalb des maximalen E-Maschinen-Moments wird ein Druckpunkt aufgeschaltet, obwohl das Drehmoment gar nicht vom Pedalwert abhängt. Das ist ebenfalls vom Fahrer nicht nachvollziehbar.
# ÄNDERUNG: Im aktiv regelnden Limiter-Betrieb oder GRA/ACC-Betrieb soll der Zustart-Druckpunkt inaktiv sein. Das soll gelten unabhängig von der relativen Lage des maximalen E-Fahr-Momentes zum Regelmoment des FAS.
# ------------------------------------
# IST: Um für ein aktives Fahrpedal aus einem Schwellen-Drehmoment einen Pedalwert zurückzurechnen kommt eine Adaption zur 'inversen Fahrpedalinterpretation' zum Einsatz. Eine Eingangsvariable ist dabei der Fahrpedalfußpunkt. Der Einfachheit halber wird applikativ umschaltbar provisorisch als Fahrpedalfußpunkt das Schubmoment bzw. 0 Nm genutzt.
# PROBLEM: Dadurch wird die Berechnung des Druckpunktes vor allem im unteren Drehzahlberech unscharf und die volle E-Fahr-Performance kann vom Fahrer u.U. nicht abgerufen werden, weil der Druckpunkt knapp unterhalb der elektrischen Volllast liegen kann.
# ÄNDERUNG: Mit Umsetzung des CR536711 wird eine präzise Berechnung des Fahrpedal-Fußpunktes für die inverse fahrpedalinterpretation in der %PtTqLoss möglich. Diese soll analog der Standard-Fahrpedalfußpunktberechnung (Eingang=aktueller Pedalwert) für den Druckpunkt (Eingang=Druckpunkt-Pedalwert) umgesetzt werden.
# ------------------------------------
#
# Aktuell wird das Motor-Erststart-Info-Bit (Eng_bStrtFirstPrmReq_VW = LV_STST_ST_PRM_FIRST) nicht in der Funktion PtTqLoss (1.35.4.5 Kompensation_Startüberschwinger) eingelesen. Dass hat zur Folge, dass infolge eines STST-Starts mit angeforderten Erststartparametern (z.B. über lange Abstellzeiten) die Ausblendfunktion nicht aktiviert wird, weil das Bit PtTqLoss_bCmpAftStrtAcv_VW nicht gesetzt wird. Ein STST-Start mit angeforderten Erststartparametern soll aber vor Kunde, im Hinblick auf den Startüberschwinger und den Drehzahlabbau mit Ausblendung, das gleiche Verhalten haben, wie ein über Schlüssel ausgelöster Erststart. Bei dem aktuellen Stand erfolgt bei diesen Randbedingungen noch ein Startüberschwinger mit Drehzahlabbau ohne Ausblendungen..
#
# ------------------------------------
# Aufgrund einer für der Schleppstart notwendigen Bedatung in der PtOpp, sind bestimmte VKM - Stellgrenzen Pt_tqEngXYZSet/LeadMaxUnLim_VW im elektrischen Fahren ungleich 0 Nm. Da es sich um unlimitierte VKM-Stellgrenzen handelt, beinhalten diese keine Info über Triebstrangszustand - elektrisch, hybridisch, d.h. die K0-Grenzen sind nicht in der Info enthalten.. Dieses führt in der Folgeberechung zwar dazu, dass im elektr. Betrieb VKM-Sollmomente = 0 Nm sind, bestimme Zwischengrößen referenzieren aber die fälschlicherweise unlimitierten Grenzen. Beispiel: Triebstrangssollmoment mit dem die Fahrerwunsch-Formung im neg. Lastwechsel initialisiert wird, enthält im E-Fahren einen VKM-Anteil aus Pt_tqEngMaxSetUnLim. Damit werden Momente gefordert und einkoordiniert, die zu dem Zeitpunkt nicht gestellt werden können und es kommt zu unkomfortablem Verhalten.;
# In der Koordination der Momente in der %DistTqSet soll eine geeignete Größe verwendet werden, die die K0-Grenzen berücksichtigt. Damit steht die richtige Information zur Verfügung, wieviel VKM-Moment für den Vortrieb zur Verfügung steht und die Momentenkoordination kann korrekt erfolgen.;
# Nur PT betroffen.
# ------------------------------------
# Bei der Berechnung des zu kompensierenden Moments eines Sprungs des P-Anteils ist die Berechnung für den Fall fehlerhaft, dass bereits ein zu kompensierendes Restmoment vorhanden ist.;
# Wird auf den aktuellen P-Anteil bereits ein Kompensationsmoment addiert und es kommt zu einem erneuten Sprung des P-Anteils, z.B. duch einen Parametersatzwechsel, wird das neue zu kompensierende Moment inkorrekt berechnet. Es ist um das zu kompensierende Restmoment des letzten Sprungs des P-Anteils zu groß.;
# Das Moment am Ausgang der Drehzahlregelung springt bei Wechsel des P-Parameter. Der Fahrer bemerkt einen Ruck des Fahrzeugs.;
# Lösungsvorschlag:;
# Es ist bei der Berechnung des zu kompensierenden Sprungmomentes zu berücksichtigen, dass es ein zu kompensierendes Restmoment geben kann und dieses ist entsprechend in die Berechnung zu ziehen.;
# Es kommt nicht mehr zu Momentensprüngen am Ausgang der Drehzahlregelung. Der Fahrer bemerkt keinen Ruck des Fahrzeugs.
# ------------------------------------
# IST: Sämtliche haptische Anzeigefunktionen auf dem aktiven Fahrpedal sind per Variantencodierung deaktivierbar. Der Fahrer selbst hat aber keine Möglichkeit, sie zu deaktivieren.
# PROBLEM: Das Bedien- und Anzeigekonzept sieht vor, dem unzufriedenen Kunden die Möglichkeit zu geben, den Fahrpedal-Druckpunkt und den haptischen Hinweis zu deaktivieren. Die Umsetzung kommt dieser Forderung nicht nach.
# ÄNDERUNG: Die Ansteuerfunktion muss um eine BAP-Schnittstelle zum MMI erweitert werden.
# Neue Codesharing-Adapter-Schnittstellen:
# - „Setup“: jeweils Aktiv-Bit MMI-->MSG und Handshake MSG-->MMI mit NV-Speicherung; Urstart ist aktiv; Umschaltung nur wenn Pedal-Fid gesetzt
# - „ModificationState“: Wenn Pedal-Fid gestzt, dann 1, ansonsten 0
# - „ModificationReason“: Status=4, wenn die Pedal-Fid nicht gesetzt
# ------------------------------------
#
# Zur Berechnung der Regeneration des Rußpartikelfilters benötigen die entsprechenden Funktionen ein Sollmoment auf dem Leadpfad ohne externe und dynamische Eingriffe. Dieses Sollmoment muss von den Pt-Funktionen berechnet werden, und als Schnittstelle für den Zulieferer zur Verfügung gestellt werden. Es muss das gefilterte Fahrerwunschmoment auf dem Leadpfad das Moment des Anfahrreglers und die Lastpunktverschiebung beinhalten.
#
# ------------------------------------
# Problem: Wenn die Zündwinkelfreigabe wegfällt wird das Sollmoment zurück Richtung Basismoment gerampt. Wenn während diesem Zustand wieder eine Zündwinkelfreigabe mit Rampe kommt, bevor das Basismoment erreicht ist, tritt das Problem auf. Die Funktion springt dann wieder in die Rampe Richtung Sollmoment, aber initialisiert falsch. Daraus resultiert ein Sprung auf dem Sollmoment. Im schlimmsten Fall springt das Sollmoment auf das Basismoment und wird erst dann wieder Richtung gefiltertem Fahrerwunschmoment gerampt. Der Fahrer erlebt dadurch einen nicht nachvollziehbarenen Ruck, bzw Momentenanstieg im Fahrzeug.
# Anforderung: Das Sollmoment muss kontinuierlich von seinem letzten Wert Richtung gefiltertem Fahrerwunschmoment gerampt werden.
# ------------------------------------
# Mit der Anforderung 536677 wurde der Entfall vom Begrenzungen des Sollmomentes mit dem Basismoment in der Funktion DistTqSet umgesetzt. Die Umsetzung ist in folgenden Punkten fehlerhaft:;
# 1. Problem: Erfolgt eine Zündwinkelfreigabe mit Rampe, wenn das gefilterte Fahrerwunschmoment größer als das Basismoment ist, dann springt das Sollmoment vom gefiltertem Fahrerwunschmoment auf das Basismoment und wird erst dann wieder Richtung gefiltertem Fahrerwunschmoment gerampt. Dadurch ist auf dem Sollmoment ein unschöner Sprung zu sehen, der zu einer ungewollten Zündwinkelrücknahme führen kann. Der Fahrer kann dadurch einen nicht nachvollziehbaren Ruck im Fahrzeug spüren.
# Anforderung: in diesem Fall muss als Sollmoment weiterhin das gefilterte Fahrerwunschmoment ausgegeben werden.;
# 2. Problem: Ist das gefilterte Fahrerwunschmoment während der Rampe Richtung Basismoment kleiner als das Basismoment, wird das Sollmoment immer auf das gefilterte Fahrerwunschmoment gedeckelt. Die Rampe Richtung Basismoment ist nicht wirksam. Dadurch bleibt der Zündwinkel länger freigegeben als notwendig, was zu einer Wirkungsgradverschlechterung des Motors führt.
# Anforderung: in diesem Fall muss das Sollmoment Werte größer als das gefilterte Fahrerwunschmoment aber kleiner gleich dem Basismoment annehmen dürfen.
# ------------------------------------
# Ist:
# Die Momenten-Eingriffshöhe von ASR-Eingriffen wird nach unten durch das aktuelle Schubmoment begrenzt (VehDynCtl_Esc). Niedrigere Eingriffe werden entsprechend begrenzt.;
# Problem:
# Auf dem genutzten Signal für das Schubmoment kann zusätzlich zu einem Verbrenner-Schub, auch ein erhöhtes Schubmoment liegen (z.B. über Lenkrad-Paddel vom Fahrer ausgewählt). Dadurch kann das Eingriffsmoment so weit in den negativen Bereich gehen, dass unerwünscht hohe Verzögerungen möglich sind.;
# Soll:
# Zusätzliche Begrenzung von ESP-Eingriffen nach unten durch einen Parameter. Dadurch kann das Eingriffsmoment zusätzlich nach unten begrenzt werden.
# ------------------------------------
#
# In bestimmten Projekten soll die Solldrehzahl bei warmen Motor während und kurz nach Motorstart aus Start/Stop (St-St Start) niedrig sein, um einen großen Drehzahlüberschwinger zu vermeiden. Aktuell kann diese Forderung aber nicht erfüllt werden. Grund dafür ist, dass die Bildung der Solldrehzahl in Abhängigkeit vom Motorzustand (Stop, Start, Cranking, Running) bei jedem Motorstart berücksichtigt wird und nicht nur beim Erststart.
#
# ------------------------------------
# Ist:
# Das Bremsblending wird bei PHEV-Fahrzeugen im ESC durchgeführt.
# Dazu schickt das ESC an das MSG ein Sollmoment ('ESCGeneratorSollmoment'), welches im MSG in den Momentenpfad einkoordiniert wird.
# Zusätzlich wird vom MSG an das ESC das maximal verfügbare Rekumoment ('TSMomRad_verfügb_MaxReku') übermittelt. Das ESC muss damit sein Sollmoment begrenzen.
# Aufgrund von Rasterverzügen oder z.B. während einer Inbetriebnahme kann es den Fall geben, dass das geforderte Reku-Sollmoment höher ist als das verfügbare Rekumoment.
# Befindet sich das Fahrzeug in P oder N sind die verfügbaren Rekumomente 0. Wird in dieser Situation vom ESC ein Moment ungleich 0 gefordert, wird dieses auch einkoordiniert. Das kann z.B. zu einem ungewollten Hochdrehen der EM führen.;
# Soll:
# Reduktion des einzukoordinierenden Rekumomentes auf das maximal verfügbare Rekumoment.
# Theoretisch sollte das schon seitens ESC sichergestellt sein.
# ------------------------------------
# Der I-Anteil des Drehzahlregler soll direkt nach Beendigung des Motorstarts auf einen Wert initialisiert werden, der der Differenz aus aktuellem Motormoment und gesamter Vorsteuerung entspricht. Diese Forderung ist so nicht umgesetzt und soll, wie im Attachment beschrieben bzw. dargestellt, korrigiert werden.
# Grund für die Initialisierung des I-Anteils ist, dass nach dem vorgesteuerten Motorstart der u. U. viel zu große I-Anteil laut beschriebener Berechnung auf ein 'normales' Momentenniveau einläuft. Somit wird ein harmonischer Drehzahlhochlauf gewährleistet.
# ------------------------------------
# Die Zwischengasfunktion für Handschalter (MtShiftSync) synchronisiert im Übergang von geöffneter zu geschlossener Kupplung die Motordrehzahl auf die Getriebeeingangsdrehzahl auf, um ein komfortables Einkuppeln zu gewährleisten. Per Applikation kann entschieden werden ob die Synchronisation bei Runter- oder Hoch- und Runterschaltungen getriggert werden soll. Wenn die Synchronisation nur bei Runterschaltungen aktiviert ist, würde nie eine Synchronisation ausgelöst werden, wenn der Fahrer aus der Neutralposition kommend einen Gang einlegt (z.B. wenn der Fahrer im Handschalter 'segelt' und anschließend wieder einkuppelt). Dies führt in dieser Situation zu einem unkomfortablen Einkuppelvorgang.
# In Zukunft soll die Funktion (wenn sie nur bei Runterschaltungen aktiv ist) auch dann getriggert werden, wenn der Fahrer aus der Neutralstellung heraus einen Gang einlegt.;
# Anforderung betrifft nur PT.
# ------------------------------------
#
# Um Applikationsaufwand zu sparen und Fehlapplikation zu vermeiden sollen in der Berechnung des prädizierten Fahrerwunschmomentes die identischen Kennfelder wie zur Berechnung des Fahrerwunschmomentes verwendet werden. Für die Berechnung des Fahrerwunschmomentes muss das Kennfeld mit dem Istwert adressiert werden und anschließend muss das identische Kennfeld für die Berechnung des prädizierten Fahrerwunschmomentes mit dem prädizierten Wert  adressiert werden. In der CordTqVeh_Ax1d wurde zur Berechnung des prädizierten Fahrerwunschmomentes eigene Kennfelder angelegt. Die Kennfelder CordTqVeh_tqCluSumAx1MaxPred_M_VW und CordTqVeh_tqCluAx1MaxPred_T_VW müssen entfallen.
#
# ------------------------------------
# Es gibt die Vorgabe die Maxdrehzahl in den Gängen 1-3 für eine applizierbare Zeit überdrehen zu können, für bessere Performance bei Volllastbeschleunigung mit weniger Schaltungen =>  nMax 6200rpm bzw. 6500rpm.
# Umgesetzt wird dies in der %SpdDesMax zur Temporären Überdrehzahl.
# Die dafür vorgesehene Kennlinie ist übersetzungsabhängig und es kann nicht zwischen ML-Getriebe und DL-Getriebe unterschieden werden.
# Da die Übersetzung im ML322 im 3. Gang länger ist als die Übersetzung im DL382 im 4. Gang ist es mit einer gemeinsamen Kennlinie nicht möglich eine Überdrehzahl im 3. Gang für beide Getriebe zu realisieren.
# ------------------------------------
# Mit der Anforderung 545526 'Momentenkoordination bei Momentenbandeinstellung für Diagnosen' wurde die Zielmomentenberechnung des Verbrenners geändert. Bei einer aktiven Momentenbandanforderung durch Diagnosen wird als Zielmoment immer das Basismoment ausgegeben. Das passiert auch wenn Schubabschalten angefordert ist und die Lastpunktverschiebung deaktiviert ist. Dadurch wird das aus der Momentenbandanforderung resultierende Sollmoment für die Elm nicht mehr in die Momentenstruktur ein koordiniert, aber für den Verbrenner wird weiterhin das Basismoment als Zielmoment gefordert. Der Verbrenner geht nicht ins Schubabschalten. Durch den schlechten Betriebspunkt ist der Kraftstoffverbrauch unnötig hoch.
# Lösung:
# Das Zielmoment für den Verbrenner darf bei einer aktiven Momentenbandeinstellung für Diagnosen nur dann auf das Basismoment geschalten werden, wenn zusätzlich die Lastpunktverschiebung aktiv ist.
# ------------------------------------
# Ist:
# Aktuell wird zur Umrechnung einer Leistung in ein Radmoment das Signal 'Veh_cirmTireRe_VW' als Radumfang genutzt.
# Definiert ist der Wert als Reifenumfang des hinteren Rades. Die Umrechnung bezieht sich jedoch nicht auf eine bestimmte Achse.
# In einigen Projekten wird der Wert aus dem AdpCus bereit gestellt.;
# Soll:
# Sinnvoller ist es 'Veh_rdWhl_VW' als allgemeinen Reifenradius zu nutzen.
# Der Wert ist nicht auf eine Achse bezogen, und ist 'das Standardsignal' für den Reifenradius.
# ------------------------------------
# Bei Diesel-Projekten Aktuell ist es in konventionellen Projekten und im Hybridbetrieb möglich die Fahrbarkeitsfilter sanft in die Rauchgrenze einlaufen zu lassen. Dadurch wird einem Momentenknick im Ist-Moment vorgebeugt und es ist für den Fahrer harmonischer.
# Bei Diesel-Hybrid-Projekten beträgt die Rauchgrenze im elektrischen Fahren Null Nm. Dadurch führt diese Funktionalität in den Fahrbarkeitsfiltern zu einem unplausiblen Momentenaufbau im elektrischen Fahren.;
# Es soll eine Möglichkeit geschaffen werden, auch bei Diesel-Hybrid-Projekten den Einlauf in die Rauchgrenze so darzustellen, dass es sowohl im elektrischen als auch im hybridischen Betrieb keinen Knick im Ist-Moment gibt.
# ------------------------------------
# Iststand: Die Betriebsstrategie nutzt für das elektrische Fahren bzw. Verbrauchssenkung möglichst die ganze zur Verfügung stehende elektrische Energie.
# Möchte der Fahrer nun nach dem Abstellen des Fahrzeugs eine elektrische Standklimatisierung bzw. Standheizung nutzen, ist dies höchstwahrscheinlich nicht möglich.;
# Sollstand: Um bei sehr kalten bzw. sehr warmen Aussentemperaturen (Haupteinsatzgebiet Standklimatisierung) die Verfügbarkeit zu erhöhen (nicht zu garantieren), soll von der BS aussentemperaturabhängig (applizierbar) ein Energievorhalt
# (applizierbar) für eine elektrische Klimatisierung reserviert werden.;
# Umsetzungsvorschlag: Teil 1: Anhebung Min-Ladezustand für BS bei längerer Fahrt im Sustainingbetrieb aussentemperaturabhängig applizierbar.
# Teil 2: Genereller Vorhalt einer aussentemperaturabhängigen Energiereserve (applizierbar).
# ------------------------------------
# Mit dem CR 363300 sollten alle MSG-internen Momentengrößen auf Radebne so angepasst werden, dass alle MSG-interne Größen, und damit auch alle an den Bus ausgegebenen Signale, um das Getriebeverlustmoment korrigiert werden. Damit sollten die Momentensignale genauer werden, um so den Fahrkomfort zu erhöhen.;Der CR363300 ist noch nicht in allen betroffenen Modulen umgesetzt. Damit sind die Getriebeverluste noch in keinem Bussignal berücksichtigt. Dies ist aber für die Bremsrekuperation, den Mastershift und für GRA/ACC ein Teil der Signalefinitionen und Vereinbarungen. Der Fahrkomfort ist dadurch beeinträchtigt.
# Alternativ zur Umsetzung des CRs363300 sollen nun nur die Bussignale korrigiert werden. Beide Varianten werden in der PtOpp koordieniert. Siehe Attachment.
# ;
# Nur PT betroffen:
# PtOpp
# PtCom
# DrvDem (wird nicht umgesetzt da nur Reku betroffen, Ossig 27.01.2014)
# VehDynCtl
# ------------------------------------
# Das Konzept der Segelnden GRA sieht vor, dass eine Abweichung von der eingestellen Setzgeschwindigkeit zugelassen wird, um möglichst lange Freilaufphasen zu erreichen.
# ...
# ------------------------------------
# Schließen offener Schnittstellen für PMD104A0QP1314_5.1.0
#
# Basis: AdpCus 9212.1.x
# Zielversion: AdpCus 9213.1.x
# ------------------------------------
# In Fahrzeugen ohne verbaute EPB gibt es das Assistenzsystem 'ACC Follow to Stop'. Das System kann das Fahrzeug in den Stillstand bremsen, und dann muss der Fahrer übernehmen. D.h. entweder betätigt er die Bremse um das Fahrzeug zu halten, oder das Fahrzeug fährt wieder an. Für die Übernahme hat der Fahrer 1,5 Sekunden Zeit in denen das Fahrzeug von der Bremse gehalten wird. Danach wechselt das ACC in Standby (Stoppverbot vom ACC wird zurückgenommen) und die Bremse gibt wieder frei bzw. löst wieder, so dass das Fahrzeug wieder ankriecht. Allerdings steht die Haltebestätigung (Bremse hält Fahrzeug autonom) in diesem Fall noch ca. 60ms an. Wenn in der Zeit vor Wegnahme der Haltebestätgung eine nachträgliche Stoppanforderung vom Fahrer (z.B. Aktivierung Start/Stopp über Taster) generiert wird, würde der Motor bei Wechsel des ACC von Aktiv auf Standby abgestellt werden. In dieser Situation darf der Motor aber nicht mehr abgestellt werden, da dass Fahrzeug 60ms später nicht mehr aktiv gehalten ist und verrollen kann.
# ------------------------------------
# Bisher kann im Modul CENox_NoxFilLoadEstim lediglich ein Auskühlen des Katalysators detektiert werden.
# Es ist aber zusätzlich gewünscht, eine Klassifizierung über das Katalysatoraufheizen vornehmen zu können.
# ------------------------------------
# Schließen offener Schnittstellen für DMG1008AH1P1492_1.1.0
#
# Basis: AdpCus 3302.1.x
# Zielversion: AdpCus 4700.1.x
# ------------------------------------
# Das Getriebeschutzmoment wird derzeit in die obere Reglergrenze des TSK einkoordiniert.
# Beim Anbinden nach dem Freilauf verwendet das DL-Getriebe das Getriebeschutzmoment, um das Motormoment während des Anbindevorgangs zu deckeln.
# Der TSK begrenzt währenddessen seinen I-Regler so, dass das Ausgangsmoment nicht das angeforderte Getriebeschutzmoment überschreitet.
# Dies führt beim Anbinden im Limiterbetrieb zu einem stark verzögerten Motormomentenaufbau. Darüber hinaus wird von der Getriebeentwicklung beanstandet, dass in dieser Situation das am CAN angezeigte Fahrerwunschmoment entgegen der Signalspezifikation auf den Getriebeschutzeingriff limitiert ist.
# Deshalb soll es ermöglicht werden, das Getriebeschutzmoment nicht in die Reglergrenze einzurechnen sondern statt dessen nur den Regler-I-Anteil zu begrenzen, wenn ein Getriebeschutzeingriff die TSK-Momentenanforderung unterstimmt.
# Details siehe Anhang
# ------------------------------------
# Die Multiplikation  'CEEgt_tiLockReqNoxSeq4_VW*CEEgt_fac_tiLockReqNoxSeq4_C_VW'   ist falsch implementiert.
# Der Fehler ist zu korrigieren und die Implementierung an die Quantisierung der Signale anzupassen.
# ------------------------------------
# Ist:
# In der SysOpmHvES wird die Schubübernahme berechnet: Bei hohem Batterieladezustand (über 97%) wird in einer Schubphase die Schubübernahme durch die VKM ausgelöst.
# Die Schubphase wird derzeit über das geforderte Moment CordTqVeh_tqAx1Dem_VW ausgelöst. Dieses Signal beinhaltet die Elm-Grenzen. Bei weiter steigendem SOC zieht sich die Momentengrenze der E-Maschine zu und die Schuberkennung über die Momentengrenze schlägt fehl. Die Schubübernahme kann nicht erfolgen.
#
# SOLL:
# Auch bei sehr hohem SOC soll eine Schubübernahme möglich sein.
# Die Schubphase sollte über die Pedalerie erkannt werden. Eine Schubphase sollte durch ein Treten des Bremspedals bei nicht getretenem Gaspedal eingeleitet werden.
#
# Der entsprechende PFIFF-Punkt ist im Anhang dargestellt. Ansprechpartner ist Thomas Krauss, PAG. Die Einlastung erfolgt für den Cayenne D1716V13C000.
# ------------------------------------
# Um den Stand und den Losfahrwunsch des Fahrers frühzeitig zu erkennen wird bei Fahrzeugen mit Automatikgetriebe bisher der Bremsenstatus Brk_st_VW ausgewertet. Dieser wird allerdings nicht
# gesetzt, wenn das Fahrzeug aufgrund eines ACC Eingriffs bis zum Stand herunterbremst.
# In diesem Fall wird der LoSpd Betrieb nicht ausgelöst.
# ------------------------------------
# Bisher war in der VLCTra nur der Teil der segelnden GRA ohne Vorausschau umgesetzt. Um zukünftig die prädiktiven Streckendaten von PEA auch für die GRA nutzen zu können, muss die Funktionslogik der VLCTra entsprechend erweitert werden.
# Ziel der Funktionslogik ist es die Freilaufphasen möglichst effizient und zugleich komfortabel zu wählen.
# ------------------------------------
# Ist:    Aufgrund einer fehlerhaften Abfrage in der Hierarchie 20_10_10_TSK_Freilauf_möglich der Eingangsgröße CordFreWhlAx_stPhdFreWhl_VW auf größer gleich 1 ist es derzeit nicht möglich eine Freilaufphase anzufordern. Die Größe wurde einfach falsch interpretiert.
# Soll:   Die Eingangsgröße CordFreWhlAx_stPhdFreWhl_VW muss in Zukunft auf ungleich 1 abgefragt werden.
# ------------------------------------
# IST:
# Aktuell kann nicht applikativ festgelegt werden, ob beim Flashen des Steuergeräts die Kurzzeit- und Langzeitkupplungskennlinien erhalten bleiben sollen.
#
# SOLL:
# Durch eine veränderte Methode zum Ablegen der Kupplungskennlinien im NVRAM kann applikativ festgelegt werden, ob beim SG-Flash die Kennlinien erhalten bleiben
#
# ######
# 28.03.2014, A. Ascioglu im Auftrag M. Huber: CR wg. Rückmeldung von Dr. Birkhold (PAG) auf 'Rejected' gestellt, Begründung: Ergebniss K0-CCB
# ------------------------------------
# IST:
#
# Die Berechnung der Reibenergie pro Start (Clu0SysDiag_wThmStressStrt_VW) ist zwischen zwei applizierbaren Momentenschwellen aktiv. Ein Reset des letzten Wertes erfolgt beim Öffnen der K0 bzw. beim Passieren der oberen Momentenschwelle. Für den Fall einer aktiven Adaption/Testeradaption wird die obere Momentengrenze nicht erreicht, sodass vor dem nächsten Reibevent kein Reset erfolgt.
#
# SOLL:
#
# Beim Ende jeder aktiven Adaption soll Clu0SysDiag_wThmStressStrt_VW zurück auf Null gesetzt werden.
# ------------------------------------
# Im Modul VLCVehA wird eine Erkennung von Schlupfsituationen berechnet.
# Diese Berechnung wird benötigt, um im TSK ein Vertrimmen des Reglers zu verhindern, da in Schlupfsituationen keine gültigen Radgeschwindigkeiten und somit Fahrzeugbeschleunigungen ermittelt werden können.
# Diese Eingangsgröße muss im TSK als Reglereinfrierbedingung berücksichtigt werden.
# ------------------------------------
# Im Modul VLCCtl wird ein ASR-Eingriff der Bremse eingelesen, um im TSK ein ungewolltes Vertrimmen des Reglers zu verhindern, da in Schlupfsituationen keine gültigen Radgeschwindigkeiten und somit Fahrzeugbeschleunigungen für den Regelalgorithmus ermittelt werden können.
# Da sich das Fahrzeug nach ASR-Eingriffen (z.B. bei Anfahren auf low-mü) nicht sofort stabilisiert, können die o.g. Reglereingangsgrößen auch noch nicht verwendet werden.
# Im TSK soll ein TurnOffDelay zur Verlängerung der Reglereinfrierbedingung bei bzw. nach ASR-Eingriffen verwendet werden können.
# ------------------------------------
# Im Modul PtCom wird das Bussignal  Mo_Mom_Ist_Summe gebildet.
# Wahlweise (applikati) kann dies über die Sollmomente geschehen. Hierbei tritt das Problem auf, dass die Nachstartkompensation in Mo_Mom_Ist_Summe sichtbar ist, dieser Beitrag ist aber fehlerhaft  zu viel und muss daher korrigiert werden.
# Über ein fehlerhaftes Bussignal MO_Mom_Ist_Summe werden Getriebeschaltungen und die Reku-Funktionalität in Richtung eines negativen Fahrverhaltens beeinflusst.
# ------------------------------------
#
# Die modellierte Temperatur am Frontendküghlerauslass bildet in dynamischen Fahrsituationen die tatsächliche Temperatur nur unzureichend ab. Hier scheint eine Abhängigkeit von der Fahrgeschwindigkeit und dem Kühlmittelmassenstrom zu bestehen.
#
# ------------------------------------
# Problem: Ist das Fahrerwunschmoment incl. ext. Eingriffe und Anfahrregler (_tqDemSetWoutMon in der CordTqIntv) hinsichtlich des zulässigen Moments der Überwachung plausibel, aber das Basismoment zu hoch. Dann führt dies aktuell zu einem An- oder Durchprellen der Überwachung mit anschließendem Notlauf, da die Begrenzung auf dem Set-Pfad zwar zur Freigabe des Zündwinkels und der Ausblendung führt aber nicht zu einer Limitierung des Moments.
#
# Grund:  Zündwinkel und Ausblendfreigabe werden in dem Fall in der DistTqSet zwar gesetzt, als Sollmoment DistTqSet_tqDesEng_VW wird aber weiterhin das Basismoment ausgegeben.
#
# Lösung: Liegt das Basismoment über dem zul. Moment der Überwachung, muss das Sollmoment DistTqSet_tqDesEng_VW auf dem Fahrerwunsch (CordTqIntv_tqDemWoutIntv_VW) + ext. Eingriffe bleiben und Zündwinkel und Ausblendung müssen freigegeben werden.
# ------------------------------------
# Eine Limitierung der Kühlmitteltemperatur für den Fall, dass das Gas eine niedrigere Temperatur als das Kühlmittel aufweißt, ist derzeit nicht möglich. Dies führt dazu, dass die
# Kühlmittelaustrittstemperatur zu niedrig modelliert wird, was sich negativ auf die hierauf folgende Rechenkette auswirkt und somit für systematische Abweichungen des Modells sorgt.
# ------------------------------------
# Bei der Lib Integration traten die im Anhang genannten Integrationsprobleme auf. Die Probleme wurden wie angefügt temporär gelöst.
#
# Betroffene Funktionen:
# PtCom
# PtTqLoss
# ------------------------------------
# Bei der Lib Integration traten die im Anhang genannten Integrationsprobleme auf. Die Probleme wurden wie angefügt temporär gelöst.
#
# Betroffene Funktionen:
# DispHyb_HvBattSoc
# HvBattSof
# PtTqLoss
# PtIntv_Cord
# CordTqLim
# DrvRcpStep
# ------------------------------------
# Ist:
# In der Funktion Clu0AdpMain wird während eines Starts oder wärend einer aktiven Adaption der K0-Kupplung, die Abweichung des übvertragenen zum angeforderten Moment berechnet. Falls diese Adaptionen erfolgreich verlaufen sind wird Bit 0 des Statuswort Clu0AdpMain_stAdp_VW gesetzt.
# Diese Info wird benötigt, da eine Anforderung eines Phantomstarts nur bei erfolgreicher passiver Adaption zurück genommen werden soll.
#
# Soll:
# Zur unterscheidung ob es sich um eine passive oder aktive Adaption gehandelt hat, soll im Falle einer passiven erfolgreichen Adaption ein zusätzliches Bit in der dieser Bitleiste gesetzt werden
# ------------------------------------
# Ist:
# in der Clu0AdpMain wird das angeforderte Soll- und das berechnete Ist-Moment ausgegeben. Mit diesen Informationen wird in der Clu0AdpCord die Kupplungskennlinie verschoben.
#
# Soll:
# Die Anforderung eines Phantomstartes soll in Abhängikeit der letzten Differenz der passiven Kupplungsadaption stattfinden.
# Dazu wird die Schnittstelle Momentendifferenz bei der letztes erfolgreichen passiven Adaption benötigt.
#
# ######
# 28.03.2014, A. Ascioglu im Auftrag M. Huber: CR wg. Rückmeldung von Dr. Birkhold (PAG) auf 'Rejected' gestellt, Begründung: Ergebniss K0-CCB
# ------------------------------------
# Mit CR 5682778 wurde die Möglichkeit geschaffen, auf schnelle Reglerparameter im Kriechregler umzuschalten, wenn das MSG von der Batterie die Freigabe erweiterter Grenzen anfordert. Damit wird erreicht, dass ein zurückrollendes Fahrzeug innerhalb des kurzen Zeitfensters, in dem die erweiterten Grenzen zur Verfügung stehen, elektromotorisch zum Stillstand gebracht werden kann. Die häufige Nutzung der erweiterten Batteriegrenzen kann der Batterie jedoch schaden, da die zulässige Ladestromgrenze überschritten wird.
#
# In Fahrversuchen hat sich herausgestellt, dass es in den meisten Fällen hinreichend ist, innerhalb der normalen Grenzen mit schneller Kriechregelung die Anforderungen an das Halten am Berg zu erfüllen.
#
# Lösung: Der Kriechregler soll nicht nur wie bisher aufgrund der Anforderung erweiterter Grenzen, sondern auch aufgrund eines explizit dafür vorgesehenen Anforderungssignals von der E-Maschine auf schnelle Parameter umschalten, damit eine häufige Anforderung erweiterter Grenzen vermieden werden kann.
# ------------------------------------
# In den Fahrbarkeitsfiltern gibt es für Projekte mit Wandlerautomaten die Möglichkeit, bei offenem Wandler den Fahrerwunsch zu entkoppeln (--> Moment aus Fahrpedalkennfeldern wird ignoriert) und die Momentenformung bei einem Lastwechsel über eine 'Drehzahlregelung' (LoadCycleControl) abhängig von Motor- und Turbinendrehzahl zu gestalten.
# Für diese Regelung kann eine Zeit vorgegeben werden, wie lange die LoadCycle maximal aktiv sein darf.
# Unter Umständen wirkt diese Maximalzeit nicht und die LoadCycle wird nicht rechtzeitig abgebrochen. Dies kann zu Verzögerungen im Lastaufbau und zu unplausiblem Fahrverhalten führen.
#
# Beschreibung der Situation:
# Der Fahrer reduziert den Momentenwunsch und dabei wird die LoadCycle-Funktion aktiviert. Reduziert der Fahrer den Fahrerwunsch noch weiter, führt dies dazu, dass der niedrige Fahrerwunsch verhindert, dass der Timer die Funktion abbricht, da der niedrige Fahrerwunsch den Timer deaktiviert.
# Lösungsvorschlag: Der niedrige Fahrerwunsch soll nicht nur den Timer beeinflussen, sondern auch die LoadCycle deaktivieren. Damit wird der Timer bei erneuter Aktivierung wieder resetiert und einkoordiniert.
# ------------------------------------
# IST: In der Prädiktiven Betriebsstrategie werden Arrays verwendet, an welchen in Schleifen Operationen durchgeführt werden. Die Laufzeit der Schleifen sowie Wertebereiche der Indices angebenden Variablen wird aktuell manuell über Literale/Limitierung in ADD begrenzt. Dadurch ist die Konsistenz der Längen von modulübergreifend verwendeten Arrays sowie die Konsistenz von ADD-Container und Funktionsmodulen nicht sichergestellt. Außerdem ist es nicht ohne weiteres möglich, Array-Längen projektspezifisch festzulegen.
#
# SOLL: Die Begrenzung/Limitierung wird über Systemkonstanten, die die jeweiligen Array-Größen angeben, umgesetzt. Alle Module, die entsprechende Arrays nutzen, müssen dementsprechend zur Begrenzung des Array-Zugriffs die jeweiligen Systemkonstanten einlesen.
# ------------------------------------
# Derzeit wird eine Korrektur an die Wärmeleitung im Ladeluftkühler-Modellierungsmodul CacSrc_Cac (mathematisch gesehen korrekt) additiert. Intuitiver ist eine multiplikative Korrektur.
#
# Der Inhalt dieses CRs wurde aus dem CR1.0 #549637 hierher übertragen.
# ------------------------------------
# Durch den aktuell gewählten Eingriffspunkt des Reglers kann es bei starken Reglereingriffen und gleichzeitig steigenden Kühlleistungsanforderungen schnell dazu führen, dass der
# Sollpumpenmassenstrom auf den Maximalwert springt. Der Grund dafür liegt in der Berechnungskette des Sollpumpenmassenstromes welcher eine 1/x-Funktion darstellt. Die Ursache für dieses
# Verhalten ist der Eingriffspunkt des Reglers und damit die gewählte Regelungsgröße - Kühlleistung.
#
# Der Inhalt dieses CRs wurde aus dem CR1.0 #549667 hierher übertragen.
# ------------------------------------
#
# In GEMT3 wird aktuell der Fehlerstatus CPP_stDia für die interne Ersatzreaktion genutzt. Für den Serienanlauf muss diese Schnittstelle entfallen. Alternativ soll eine FID die Ersatzreaktion auslösen.
#
# ------------------------------------
# CR 546078 beschreibt eine Anforderung für elektrifizierte Konzepte, die die Möglichkeit vorsieht beispielsweise durch MSR beschränkte, rekuperative gestellte Verzögerung auf den mechanischen Bremspfad umzublenden.
# Die aktuelle Implementierung ermöglicht das jedoch nur, wenn der TSK zum Zeitpunkt der Rekuperationsbegrenzung durch MSR oder Getriebeschutz bereits ein Rekuperationsmoment unterhalb Schleppmoment gefordert hat.
#
# Das bedeutet:
# Stellt der TSK eine starke Verzögerung rein rekuperativ und ist diese Verzögerung geringer als diejenige, die sich bespielsweise im Fahrprogramm 'B' einstellen würde, so kann der TSK aktuell diese Verzögerung nicht in die mechanische Bremse rampen.
# Das soll mit dieser Anforderung korrigiert werden in der Form, dass der TSK - wenn er generell verzögert - eine mechanische Verzögerungsanforderung betragsmäßig bis zur Höhe seiner Momentenanforderung unter '0' auch dann zulässt, wenn diese sich im Bereich des Schleppmomentes des Fahrprogramms befindet.
#
# Diese Anforderung betrifft ausschließlich elektrifizierte Konzepte.
# ------------------------------------
