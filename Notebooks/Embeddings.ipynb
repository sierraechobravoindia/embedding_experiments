# %% [markdown]
# # Embeddings
#
# In this notebook I train different embeddings on domain specific corpora. The corpora are preprocessed in the notebook "Data Collection".
# Furthermore I do a few sanity checks on the objects involved.

# %%
import pickle
import gensim
from gensim.models import FastText, Word2Vec, KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.test.utils import datapath, get_tmpfile

# %%
# Load Facebook pretrained FastText in gensim, either bin or vec.
# Source: https://fasttext.cc/docs/en/crawl-vectors.html


# model = FastText.load_fasttext_format('../WordEmbeddings/FastText/cc.de.300.bin') 
model =  KeyedVectors.load_word2vec_format('../WordEmbeddings/FastText/cc.de.300.vec')

# %%
print(model.most_similar('teacher'))
# Output = [('headteacher', 0.8075869083404541), ('schoolteacher', 0.7955552339553833), ('teachers', 0.733420729637146), ('teaches', 0.6839243173599243), ('meacher', 0.6825737357139587), ('teach', 0.6285147070884705), ('taught', 0.6244685649871826), ('teaching', 0.6199781894683838), ('schoolmaster', 0.6037642955780029), ('lessons', 0.5812176465988159)]

print(model.similarity('Lehrer', 'Lehrerin'))
# Output = 0.683924396754

#print(model.most_similar(positive=['frau', 'könig'], negative=['mann']))
print(model.most_similar(positive=["Auto", "Fahrer"], negative=["Fahrrad"]))

# %%
model.wv.vectors.shape

# %% [markdown]
# # Training on domain data

# %%
# import and merge data

with open("../Data/CRQ_preprocessed.pkl",'rb') as file:
    CRQ_data = pickle.load(file)

with open("../Data/CRQ_test_preprocessed.pkl",'rb') as file:
    CRQ_test_data = pickle.load(file)
    
with open("../Data/CRQ_train_preprocessed.pkl",'rb') as file:
    CRQ_train_data = pickle.load(file)
    
with open("../Data/Patents_preprocessed.pkl",'rb') as file:
    patents_data = pickle.load(file)
    
with open("../Data/Books_preprocessed.pkl",'rb') as file:
    books_data = pickle.load(file)
    
training_data = CRQ_data + CRQ_test_data + CRQ_train_data + patents_data + books_data

# %%
print(len(CRQ_data))
print(len(CRQ_test_data))
print(len(CRQ_train_data))
print(len(patents_data))
print(len(books_data))
print(len(training_data))
# Out:
# 17552
# 966
# 8663
# 560
# 60
# 27801

# %%
print(books_data[13])
# Out:
# ['henning', 'wallentowitz', 'konrad', 'reif', 'hrsg', 'handbuch', 'kraftfahrzeugelektronik', 'programm', 'kraftfahrzeugtechnik', 'vieweg', 'handbuch', 'verbrennungsmotor', 'herausgegeben', 'van', 'basshuysen', 'schäfer', 'lexikon', 'motorentechnik', 'herausgegeben', 'van', 'basshuysen', 'schäfer', 'vieweg', 'handbuch', 'kraftfahrzeugtechnik', 'herausgegeben', 'braess', 'seiffert', 'bremsenhandbuch', 'herausgegeben', 'breuer', 'bill', 'nutzfahrzeugtechnik', 'herausgegeben', 'hoepke', 'breuer', 'aerodynamik', 'automobils', 'herausgegeben', 'hucho', 'verbrennungsmotoren', 'köhler', 'flierl', 'automobilelektronik', 'herausgegeben', 'reif', 'automotive', 'software', 'engineering', 'schäuffele', 'zurawka', 'motorkolben', 'zima', 'bussysteme', 'fahrzeugtechnik', 'zimmermann', 'schmidgall', 'bosch', 'fachbuchreihe', '•ottomotor', 'management', '•dieselmotor', 'management', '•autoelektrik', 'autoelektronik', '•sicherheits', 'komfortsysteme', '•fachwörterbuch', 'kraftfahrzeugtechnik', '•kraftfahrtechnisches', 'taschenbuch', 'herausgegeben', 'robertboschgmbh', 'henning', 'wallentowitz', 'konrad', 'reif', 'hrsg', 'handbuchkraftfahrzeug', 'elektronik', 'grundlagen', 'komponenten', 'systeme', 'anwendungen', 'abbildungen', 'zahlreichen', 'tabellen', 'atz', 'mtz', 'fachbuch', 'auflage', 'september', 'rechte', 'vorbehalten', 'friedr', 'vieweg', 'sohn', 'verlag', 'gwv', 'fachverlage', 'gmbh', 'wiesbaden', 'lektorat', 'ewald', 'schmitt', 'vieweg', 'verlag', 'unternehmen', 'springer', 'science', 'businessmedia', 'www', 'vieweg', 'werk', 'einschließlich', 'teile', 'urheberrechtlich', 'geschützt', 'verwertung', 'außerhalb', 'engen', 'grenzen', 'urheberrechtsgesetzes', 'zustimmung', 'verlags', 'unzulässig', 'strafbar', 'gilt', 'insbesondere', 'vervielfältigungen', 'übersetzungen', 'mikroverfilmungen', 'einspeiche', 'rung', 'verarbeitung', 'elektronischen', 'systemen', 'konzeption', 'layout', 'umschlags', 'ulrike', 'weigel', 'www', 'corporatedesigngroup', 'satz', 'technische', 'redaktion', 'klementz', 'publishing', 'services', 'gundelfingen', 'druck', 'buchbinderische', 'verarbeitung', 'wilhelm', 'adam', 'heusenstamm', 'gedruckt', 'säurefreiem', 'chlorfrei', 'gebleichtem', 'papier', 'printed', 'germany', 'isbn', 'isbn', 'bibliografische', 'information', 'deutschen', 'nationalbibliothek', 'deutsche', 'nationalbibliothek', 'verzeichnet', 'publikation', 'deutschen', 'nationalbibliografie', 'detaillierte', 'bibliografische', 'daten', 'internet', 'http', 'dnb', 'abrufbar', 'werk', 'entstand', 'freundlicher', 'unterstützung', 'siemens', 'vdo', 'vorwort', 'kraftfahrzeugelektronik', 'eigenständigen', 'ingenieurdisziplin', 'innerhalb', 'fahrzeugtechnik', 'entwickelt', 'gleichzeitig', 'wichtiges', 'gebiet', 'innerhalb', 'maschinenbaus', 'inhalte', 'kraft', 'fahrzeugelektronik', 'elektrotechnischer', 'elektronischer', 'regelungstechnischer', 'natur', 'klassische', 'aufteilung', 'elektrotechnik', 'antriebstechnik', 'automatisierungstechnik', 'energietechnik', 'hochfrequenztech', 'nik', 'usw', 'lässt', 'recht', 'einordnen', 'vielmehr', 'weist', 'vielen', 'gebiete', 'erhebliche', 'schneidungen', 'kommt', 'kraftfahrzeugelektronik', 'inhaltlich', 'stark', 'wandel', 'begriffen', 'inhalte', 'weitgehend', 'fahrzeughersteller', 'zulieferunternehmen', 'geprägt', 'geschlossene', 'umfassende', 'darstellung', 'kraftfahrzeugelektronik', 'daher', 'konsequenter', 'logi', 'scher', 'schritt', 'handbuch', 'kraftfahrzeugelektronik', 'helfen', 'prinzipiellen', 'überblick', 'fällen', 'tiefen', 'einblick', 'umfangreiche', 'manchmal', 'unübersichtlich', 'erscheinende', 'gebiet', 'winnen', 'meisten', 'heute', 'kraftfahrzeug', 'wichtigen', 'elektronischen', 'systeme', 'stand', 'tech', 'nik', 'beschrieben', 'herausgeber', 'bewusst', 'auswahl', 'behandelten', 'themen', 'gewissen', 'subjektivität', 'unterliegt', 'vollständige', 'abdeckung', 'gebietes', 'buch', 'vorliegenden', 'umfang', 'möglich', 'erfahrung', 'decken', 'ausgewählten', 'kapitel', 'jedoch', 'wesentlichen', 'umfang', 'fahrzeu ...

# %%
# Train FastText on local data
model_ft = FastText(training_data, size=300, window=5, min_count=5, workers=4)

# %%
model_ft.save("../WordEmbeddings/ft_ds.model")

# %%
print(len(model_ft.wv.vocab))
similarity = model_ft.wv.similarity('motor', 'starter')
print(similarity)
# Out:
# 91716
# 0.29978982

# %%
# Train word2vec on local dataa
model_w2v = Word2Vec(training_data, size=300, window=5, min_count=5, workers=4)

# %%
model_w2v.save("../WordEmbeddings/w2v_ds.model")

# %%
print(len(model_w2v.wv.vocab))
similarity = model_w2v.wv.similarity('motor', 'starter')
print(similarity)
# Out:
# 91716
# 0.62028044
